# %% [markdown]
# This file searches the semantic space for similar sentences using sentence-transformers. The semantic search codes are adapted from: https://www.sbert.net/examples/applications/semantic-search/README.html

# %%
! pip install sentence_transformers
# Out:
# ...
#      |████████████████████████████████| 79 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 43.4 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 39.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 39.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 38.4 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 43.3 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=84981706d7fb3289925b2409212744da284241249232ef5c4238f0151ce73092
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from sentence_transformers import SentenceTransformer, util
import torch
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
embedder = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import pandas as pd

# %%
quotes = pd.read_csv('drive/MyDrive/data2/mlk131quotes.csv', delimiter = '|', header = None)
quotes = quotes[0].tolist()
dfmlkwiki = pd.read_csv("drive/MyDrive/data/coding_prez/mlkwiki.csv", delimiter='|', header=None, names=['sentence', 'label'])
mlkwikilst = dfmlkwiki.sentence.values.astype('str').tolist()
dfbirmjail = pd.read_csv("drive/MyDrive/data/coding_prez/birminghamjail.csv", delimiter='|', header=None, names=['sentence', 'label'])
birmjaillst = dfbirmjail.sentence.values.astype('str').tolist()

# %%
queries = ['Life is hard.', 'Power to those who fight.', 'Black lives matter', 'Black people should unite and demand justice.']

# %%
corpus = quotes
# corpus = mlkwikilst
# corpus = birmjaillst
corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)

# %%
top_k = min(5, len(corpus))
for query in queries:
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(corpus[idx], "(Score: {:.4f})".format(score))
# Out:
# ...
#
#
# Query: Life is hard.
#
# Top 5 most similar sentences in corpus:
# A lie cannot live. (Score: 0.4074)
# The quality, not the longevity, of one’s life is what is important. (Score: 0.3722)
# There is nothing more tragic than to find an individual bogged down in the length of life, devoid of breadth. (Score: 0.3615)
# Life’s most persistent and urgent question is, what are you doing for others? (Score: 0.3452)
# A man who won’t die for something is not fit to live. (Score: 0.3400)
#
#
# ...
#
#
# Query: Power to those who fight.
#
# Top 5 most similar sentences in corpus:
# Those who love peace must learn to organize as effectively as those who love war. (Score: 0.4151)
# Your ignorance is their power. (Score: 0.4141)
# Our scientific power has outrun our spiritual power. We have guided missiles and misguided men. (Score: 0.4098)
# Courage is the power of the mind to overcome fear. (Score: 0.4038)
# ...

# %%
# corpus = quotes
corpus = mlkwikilst
# corpus = birmjaillst
corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)

# %%
top_k = min(5, len(corpus))
for query in queries:
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(corpus[idx], "(Score: {:.4f})".format(score))
# Out:
# ...
#
#
# Query: Life is hard.
#
# Top 5 most similar sentences in corpus:
#  We've got some difficult days ahead (Score: 0.4125)
#  Like anybody, I would like to live a long life (Score: 0.3555)
#  Longevity has its place (Score: 0.3414)
#  tried to give his life serving others (Score: 0.3283)
#  It was the angriest I have ever been in my life (Score: 0.3277)
#
#
# ...
#
#
# Query: Power to those who fight.
#
# Top 5 most similar sentences in corpus:
#  government "the greatest purveyor of violence in the world today (Score: 0.4384)
#  He put into words his belief that one must not use force in this struggle "but match the violence of his opponents with his suffering (Score: 0.4001)
#  and an opportunity to place organizers' concerns and grievances squarely before the seat of power in the nation's capital (Score: 0.3884)
#  this means a revolution of values and other things (Score: 0.3861)
# ...

# %%
# corpus = quotes
# corpus = mlkwikilst
corpus = birmjaillst
corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)

# %%
top_k = min(5, len(corpus))
for query in queries:
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(corpus[idx], "(Score: {:.4f})".format(score))
# Out:
# ...
#
#
# Query: Life is hard.
#
# Top 5 most similar sentences in corpus:
#
# Things are different now (Score: 0.3828)
#  These are the hard, brutal, and unbelievable facts (Score: 0.3639)
# "; when you are
# harried by day and haunted by night by the fact that you are a Negro, living constantly at tiptoe stance, never knowing what to
# expect next, and plagued with inner fears and outer resentments; when you are forever fighting a degenerating sense of
# "nobodyness" -- then you will understand why we find it difficult to wait (Score: 0.3014)
#  We must come to see that human progress never rolls in on wheels of inevitability (Score: 0.2854)
#  Abused and scorned though we may be, our destiny is tied up with the destiny of America (Score: 0.2642)
#
#
# ...
#
#
# Query: Power to those who fight.
#
# Top 5 most similar sentences in corpus:
#  The other force is one of
# bitterness and hatred and comes perilously close to advocating violence (Score: 0.4237)
# ...
